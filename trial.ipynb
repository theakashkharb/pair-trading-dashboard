# %%
from pathlib import Path
import os

print("cwd =", os.getcwd())
print("main =", Path(__file__).resolve())
print("exists =", Path("/Users/akash/PycharmProjects/Pairs Trade Dashboard/fno.csv").exists())
# Out:
# cwd = /Users/akash/PycharmProjects/Pairs Trade Dashboard
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 from pathlib import Path
#       2 import os
#       3
#       4 print("cwd =", os.getcwd())
# ----> 5 print("main =", Path(__file__).resolve())
#       6 print("exists =", Path("/Users/akash/PycharmProjects/Pairs Trade Dashboard/fno.csv").exists())
#
# NameError: name '__file__' is not defined
